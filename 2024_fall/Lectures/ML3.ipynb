# %% [markdown]
# <a href="https://colab.research.google.com/github/anishyathinesh/RIT_ML/blob/main/2024_fall/Lectures/ML3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML 3: NumPy and Pandas

# %%
import numpy as np #library for work with arrays
import pandas as pd #library for work with tables
import matplotlib.pyplot as plt #library for visualization
#import sys
#import sklearn

# %%
#sklearn.__version__

# %% [markdown]
# ## Numpy
# Useful information: https://realpython.com/numpy-tutorial/

# %%
np.__version__
# Out:
# '1.26.4'

# %%
a = [1, 2, 3]
a = np.array(a)
a #type(a[0])
# Out:
# array([1, 2, 3])

# %%
b = a #.copy()
a[1] = 5
print(a)
print(b)
# Out:
# [1 5 3]
# [1 5 3]

# %% [markdown]
# ### Shape

# %%
a.shape
# Out:
# (3,)

# %%
np.array([a]).shape
# Out:
# (1, 3)

# %%
b = a.reshape(1,-1)
#(a.reshape(-1,1)).shape
b.shape
# Out:
# (1, 3)

# %%
a.T
#b.T
# Out:
# array([1, 5, 3])

# %%
c = np.random.rand(4,3)
c
# Out:
# array([[0.15984493, 0.2223551 , 0.14386084],
#        [0.55783764, 0.06632783, 0.8793299 ],
#        [0.28936403, 0.94237627, 0.35536901],
#        [0.59763337, 0.7303591 , 0.72666283]])

# %%
c.reshape(1,-1)
# Out:
# array([[0.15984493, 0.2223551 , 0.14386084, 0.55783764, 0.06632783,
#         0.8793299 , 0.28936403, 0.94237627, 0.35536901, 0.59763337,
#         0.7303591 , 0.72666283]])

# %%
c.max(axis=1)
# Out:
# array([0.2223551 , 0.8793299 , 0.94237627, 0.7303591 ])

# %% [markdown]
# ### Broadcasting

# %%
c+c.max(axis=0)
#c+c.max(axis=1).reshape(-1,1)
# Out:
# array([[0.7574783 , 1.16473137, 1.02319075],
#        [1.15547101, 1.0087041 , 1.7586598 ],
#        [0.8869974 , 1.88475255, 1.23469891],
#        [1.19526673, 1.67273537, 1.60599273]])

# %% [markdown]
# ### Matrix Multiplication

# %%
c*c
#c.dot(c.T)
#np.matmul(c.T,c)
# Out:
# array([[0.0255504 , 0.04944179, 0.02069594],
#        [0.31118283, 0.00439938, 0.77322108],
#        [0.08373154, 0.88807304, 0.12628713],
#        [0.35716564, 0.53342441, 0.52803887]])

# %% [markdown]
# ### Change type

# %%
c.dtype
#c.astype(np.float32)
# Out:
# dtype('float64')

# %% [markdown]
# ### Problem 1.
# Assume that in rows of matrix $A = \begin{pmatrix} x^{(1)}_1 & x^{(1)}_2 & x^{(1)}_3 \\ x^{(2)}_1 & x^{(2)}_2 & x^{(3)}_3\\ \cdots & \cdots & \cdots\\ x^{(20)}_1 & x^{(20)}_2 & x^{(20)}_3 \end{pmatrix}$ we have coordinates of 20 points and in rows of matrix $B = \begin{pmatrix} y^{(1)}_1 & y^{(1)}_2 & y^{(1)}_3 \\ y^{(2)}_1 & y^{(2)}_2 & y^{(3)}_3\\ \cdots & \cdots & \cdots\\ y^{(5)}_1 & y^{(5)}_2 & y^{(5)}_3 \end{pmatrix}$ we have coordinates of 5 other points. Using boadcasting, get a matrix with Eucledean distances from every point $x^{i}$ to every point $y^{(j)}:$
# $$
# D =  \begin{pmatrix} d(x^{(1)}, y^{(1)}) & d(x^{(1)}, y^{(2)}) & \ldots & d(x^{(1)}, y^{(5)}) \\ d(x^{(2)}, y^{(1)}) & d(x^{(2)}, y^{(2)}) & \ldots & d(x^{(2)}, y^{(5)})\\ \cdots & \cdots & \cdots & \cdots\\ d(x^{(20)}, y^{(1)}) & d(x^{(20)}, y^{(2)}) & \ldots & d(x^{(20)}, y^{(5)}) \end{pmatrix}
# $$

# %%
A = np.random.randn(20,3)
B = np.random.randn(5,3)

C = A[:, None, :]
D = B[None, :, :]

sq = (C - D) ** 2
add = sq.sum(axis=-1)

ans = np.sqrt(add)

# %%
print(A)
print(B)
print(ans)
# Out:
# [[-1.07655664e+00  7.02448545e-01  2.86871829e-01]
#  [-1.07748565e+00 -9.05400060e-03 -3.19064674e-01]
#  [ 1.25681247e+00  1.57086411e+00  1.62359290e-01]
#  [ 2.95995042e-01 -3.65499215e-01 -1.51754672e+00]
#  [-2.84949185e-01 -1.85829126e+00  1.06835031e+00]
#  [ 3.71013079e-01 -7.40084087e-01 -1.08295896e+00]
#  [-3.01512972e-02 -8.20862204e-01 -1.90903527e+00]
#  [-4.07063676e-01  1.04641452e+00  8.06098788e-01]
#  [ 1.32108722e+00 -4.22624851e-01  4.79201238e-01]
#  [ 1.65394315e+00 -8.79418916e-01  1.35892106e+00]
#  [ 7.86613627e-01  1.05700950e-01  9.35651084e-01]
#  [ 1.14018267e+00 -3.00919635e-01  8.60906597e-01]
#  [-9.31195905e-01  3.26396137e-01  4.82759200e-02]
#  [ 1.66392503e-01  1.49616573e+00  2.12304528e-03]
#  [-1.44064800e-01 -7.69606916e-01 -2.38618096e+00]
#  [ 1.51749462e+00  1.74979782e-01 -8.62574868e-01]
#  [-6.36791348e-01  2.35754777e-01 -7.17451372e-01]
#  [-5.56042094e-03  2.27155218e-01  9.28951043e-01]
#  [-8.49763901e-01  1.21249097e+00 -1.35376819e+00]
#  [-6.32991789e-01 -8.06302103e-02 -7.47534618e-01]]
# [[ 0.12925498 -0.10553838 -1.29371302]
#  [-0.87109489  1.36983133  2.34741935]
#  [-0.03670941 -0.97226386 -0.98709877]
#  [-0.99653867 -0.96633656 -1.40559673]
#  [ 1.85657828 -1.14922068 -0.31950056]]
# [[2.14594339 2.17565401 2.34711419 2.37817082 3.52131323]
#  [1.55417875 3.00899633 1.56756435 1.4503428  3.14781057]
#  [2.49035294 3.05661436 3.0760287  3.73810978 2.82679486]
#  [0.38142287 4.39447764 0.87191204 1.42974883 2.11777099]
#  [2.97036209 3.52141446 2.25200766 2.72440025 2.64859416]
#  [0.71099403 4.21450716 0.47888855 1.42319468 1.71964108]
#  [0.9569326  4.8604249  0.9343085  1.09932602 2.48881264]
#  [2.45435181 1.64182595 2.72539579 3.04799028 3.34841197]
#  [2.15968352 3.3924623  2.07261922 3.03635894 1.20524551]
#  [3.15595194 3.52307715 2.89322231 3.83081808 1.71200267]
#  [2.33383949 2.51775947 2.35304823 3.13214589 2.07245224]
#  [2.38799797 3.0077178  2.29148464 3.18518369 1.62055496]
#  [1.76410256 2.52555531 1.88643172 1.94657987 3.17559277]
#  [2.06058884 2.56763611 2.66701234 3.06561599 3.15566775]
#  [1.30735493 5.24525887 1.41775385 1.31413838 2.90135265]
#  [1.48046609 4.17577453 1.93577486 2.81386551 1.47085495]
#  [1.01753894 3.27634862 1.37554247 1.43107853 2.87982881]
#  [2.25146525 2.01665836 2.260713   2.80295805 2.63070381]
#  [1.64295038 3.70459177 2.35980036 2.18438056 3.73787097]
#  [0.93805725 3.42626207 1.09906971 1.16176066 2.74281933]]

# %% [markdown]
# ### Problem 2.
# A unit ball centered in the origin (neighborhood of the origing of raduis 1) in $\ell_1$ metric is defined as
# $$
# \{(x,y)\in\mathbb{R}^2:|x-0|+|y-0|=|x|+|y|<1\}.
# $$
# To plot the boundary of this ball you can plot the surface $z=|x|+|y|$ and then take its section at the level $z=1$, you'll get the level curve
# $$
# |x|+|y|=1.
# $$
# The unit ball in $\ell_2$ metric is plotted below, plot a unit ball in $\ell_1$ metric (you can modify the existing code).

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
def f(x, y):
    return np.sqrt(x**2 + y**2)

# %%
x = np.linspace(-2, 2, 400)
y = np.linspace(-2, 2, 400)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')

# Add a color bar which maps values to colors
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

# Add labels
ax.set_title('$f(x,y) = \sqrt{x^2 + y^2}$')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$f(x,y)$')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

# Plot the function as a filled contour plot
contour = plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar(contour, label='$f(x,y)$')

# Plot the level curve f(x,y) = 1
plt.contour(X, Y, Z, levels=[1], colors='red', linewidths=2)

# Add labels and title
plt.title('$f(x,y) = \sqrt{x^2 + y^2}$ and the level curve $f(x,y) = 1$')
plt.xlabel('$x$')
plt.ylabel('$y$')

# Show the plot
plt.grid(True)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Pandas
# ### Download data
# * .csv (Comma Separated Files) [pandas.read_csv()](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
# * .xls (eXceL Spreadsheet) [pandas.read_excel()](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)
# * .json (JavaScript Object Notation) [pandas.read_json()](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)
# * .txt
#
# Save .csv file from https://www.randomservices.org/random/data/Galton.html
#
# Another source: https://raw.githubusercontent.com/data-8/materials-fa17/master/lec/galton.csv

# %% [markdown]
# F. Galton introduced the term _regression._ In the figure below you can see that "extremely tall parents tend to have children who are taller than average and extremely small parents tend to have children who are smaller than average, but in both cases the children tend to be closer to the average than were their parents". (Stephen Senn _Francis Galton and regression to the mean._ Significance, Vol. 8, Iss. 3)
#
# ![title](https://upload.wikimedia.org/wikipedia/commons/b/b2/Galton%27s_correlation_diagram_1875.jpg)
# **Francis Galton.** *Regression towards mediocrity in hereditary stature.* The Journal of the Anthropological Institute of Great Britain and Ireland. 15: 246–263 (1886)

# %%
#To see the current directory, you can type
# !pwd

# %%
# !ls

# %%
#PATH = 'Galtons Height Data.csv'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anton-selitskiy/The-Art-of-ML/main/Galtons%20Height%20Data.csv')

# %%
df.head() #df.tail(6)

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ### Dictionary and creation of dataframes

# %%
d = {'c1': [0, 1], 'c2':[3, 4]}

# %%
d['c1']

# %%
df1 = pd.DataFrame(data = d)
df1.head()

# %% [markdown]
# ### Access to Columns

# %%
df.columns #.values

# %%
for i in df.columns:
    print(i)

# %%
df.columns[0]

# %%
d = dict(zip(df.columns.values[[0,1,2,4,5]], [np.int32, np.float32, np.float32, np.float32, np.int32]))

# %%
#df2 = pd.read_csv(PATH, dtype=d)
#df2.info()

# %% [markdown]
# ### Access to Rows

# %%
df.index

# %% [markdown]
# ### Access by index

# %%
df.iloc[df.index % 2 == 0].head(5)
#df.iloc[1,2]

# %%
df.head()
# Out:
#    Family  Father  Mother Gender  Height  Kids  Sex
# 0       1    78.5    67.0      M    73.2     4    0
# 1       1    78.5    67.0      F    69.2     4    1
# 2       1    78.5    67.0      F    69.0     4    1
# 3       1    78.5    67.0      F    69.0     4    1
# 4       2    75.5    66.5      M    73.5     4    0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Family'].plot(kind='hist', bins=20, title='Family')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Father'].plot(kind='hist', bins=20, title='Father')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Mother'].plot(kind='hist', bins=20, title='Mother')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Height'].plot(kind='hist', bins=20, title='Height')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Family', y='Father', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Father', y='Mother', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Mother', y='Height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Height', y='Sex', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Family']
#   ys = series['Father']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Family', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Family')
# _ = plt.ylabel('Father')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Family']
#   ys = series['Mother']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Family', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Family')
# _ = plt.ylabel('Mother')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Family']
#   ys = series['Height']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('Family', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Family')
# _ = plt.ylabel('Height')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Family']
#   ys = series['Sex']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('Family', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Family')
# _ = plt.ylabel('Sex')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['Family'].plot(kind='line', figsize=(8, 4), title='Family')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Father'].plot(kind='line', figsize=(8, 4), title='Father')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Mother'].plot(kind='line', figsize=(8, 4), title='Mother')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Height'].plot(kind='line', figsize=(8, 4), title='Height')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='Family', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='Father', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Mother', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='Height', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
#df.columns = ['Family', 'Father', 'Mother', 'AverageHeight', 'Kids', 'Num', 'Gender', 'Height']
#df.Gender = df.Gender.map({'male': 'M', 'female': 'F'})

# %% [markdown]
# ### Visualization

# %%
plt.scatter(df[df['Gender']=='M'].Father, df[df['Gender']=='M'].Height, label="M", alpha=0.5)
plt.scatter(df[df['Gender']=='F'].Father, df[df['Gender']=='F'].Height, label="F", alpha=0.5, c='pink')
plt.xlabel("Father's Height")
plt.ylabel("Child's Height")
plt.legend()
plt.show()

# %% [markdown]
# ### Working with columns

# %%
plt.scatter(df[df['Gender']=='M'].Father, df[df['Gender']=='M'].Height-df[df['Gender']=='M'].Height.mean(), alpha=0.5)
plt.scatter(df[df['Gender']=='F'].Father, df[df['Gender']=='F'].Height-df[df['Gender']=='F'].Height.mean(), alpha=0.5, c='pink')

# %% [markdown]
# ### Delete columns

# %%
df.drop("Height", axis=1).head()  #inplace=True

# %% [markdown]
# ### View elements

# %%
set(df["Gender"])
#df.Gender.unique()

# %% [markdown]
# ### Change values

# %%
df["Sex"] = df.Gender.map({"M":0, "F":1})
print(df.Sex.dtype)
df.head()

# %%
#df["NewAge"] = df["Age"].apply(lambda x: x+100)

# %%
df.groupby("Gender")["Height"].mean()

# %%
df.groupby("Family")["Height"].count().head()
# Out:
# Family
# 1    4
# 2    4
# 3    2
# 4    5
# 5    6
# Name: Height, dtype: int64

# %%
(df.groupby("Family")["Height"].mean() > 70).sum()
# Out:
# 19

# %%
df[(df.Height > 70) & (df.Gender=="M")].head()
# Out:
#     Family  Father  Mother Gender  Height  Kids  Sex
# 0        1    78.5    67.0      M    73.2     4    0
# 4        2    75.5    66.5      M    73.5     4    0
# 5        2    75.5    66.5      M    72.5     4    0
# 8        3    75.0    64.0      M    71.0     2    0
# 10       4    75.0    64.0      M    70.5     5    0

# %% [markdown]
# ## Problems
# 3. What is the fraction of families with 3 or more children?

# %%
(df.groupby("Family")["Kids"].size() >= 3).sum() / df.groupby("Family")["Kids"].size().count()
# Out:
# 0.7360406091370558

# %% [markdown]
# 4. Create a new column with the avarage height of the parents

# %%
df['AVG Height'] = df.groupby("Family")["Mother"].mean() + df.groupby("Family")["Father"].mean()

# %%
df.head()
# Out:
#    Family  Father  Mother Gender  Height  Kids  Sex  AVG Height
# 0       1    78.5    67.0      M    73.2     4    0         NaN
# 1       1    78.5    67.0      F    69.2     4    1       70.10
# 2       1    78.5    67.0      F    69.0     4    1       69.25
# 3       1    78.5    67.0      F    69.0     4    1       69.50
# 4       2    75.5    66.5      M    73.5     4    0       66.70

# %% [markdown]
# 5* (not graded). Plot a scatterplots of male vs the avarage parents' height and females $\times 1.08$ (the guess by Galton) _"which is equivalent to adding a little less than one-twelfthto each female height. It differs a very little from the factors employed by other anthropologists, who, moreover, differ a trifle between themselves; anyhow,  itsuits my data better than 1.07 or 1.09. The final result is not of a kind to be affected by these minute details, for it happened that, owing to a mistaken direction,the computer to whom I first entrusted the figures used a somewhat different factor, yet the result came out closely the same."_ http://www.stat.ucla.edu/~nchristo/statistics100C/history_regression.pdf

# %%
#Your code
#plt.scatter(df[df['Gender']=='M'].Father, df[df['Gender']=='M'].Height, alpha=0.5)
#plt.scatter(df[df['Gender']=='F'].Father, df[df['Gender']=='F'].Height*1.08, alpha=0.5, c='pink')

# %% [markdown]
# It's a genius guess by Galton allowed him to use more data for analysis
